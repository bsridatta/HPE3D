# %%
import torch
from torchviz import make_dot, make_dot_from_trace

# %%
model = torch.nn.Sequential()

model.add_module('a', torch.nn.Linear(1,2))

x = torch.randn(1,1)

y = torch.randn(1,1)
x = x * y 
make_dot(model(x), params=dict(model.named_parameters()))

# %%
from src.processing import random_rotate_and_project_3d_to_2d
import torch
a = torch.zeros((1,17,3))
random_rotate_and_project_3d_to_2d(a)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-7ffe7ec290a1> in <module>
#       2 import torch
#       3 a = torch.zeros((1,17,3))
# ----> 4 random_rotate_and_project_3d_to_2d(a)
#
# ~/lab/HPE3D/src/processing.py in random_rotate_and_project_3d_to_2d(pose_3d, azimuth_range, elevation_range, roll_range, default_camera, default_camera_z)
#     261     rotation_matrices = create_rotation_matrices_3d(azimuths, elevations, rolls)
#     262
# --> 263     pose_3d = rotation_matrices.dot(torch.transpose(pose_3d, 1,2))
#     264     # pose_3d = tf.linalg.matrix_transpose(
#     265     #     tf.matmul(rotation_matrices, pose_3d, transpose_b=True))
#
# RuntimeError: 1D tensors expected, got 3D, 3D tensors at /opt/conda/conda-bld/pytorch_1579040055865/work/aten/src/TH/generic/THTensorEvenMoreMath.cpp:733

# %%
random_rotate_and_project_3d_to_2d
# Out:
# <function src.processing.random_rotate_and_project_3d_to_2d(pose_3d, azimuth_range=(-3.141592653589793, 3.141592653589793), elevation_range=(-0.5235987755982988, 0.5235987755982988), roll_range=(0.0, 0.0), default_camera=True, default_camera_z=10.0)>
