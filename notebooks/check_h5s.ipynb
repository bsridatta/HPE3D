# %%
import h5py
from src.viz.mpl_plots import plot_2d, plot_3d

# %%
path = '/home/datta/lab/HPE_datasets/h36m/S1/SH/'
h5 = h5py.File(path+"Directions_1.54138969.h5", 'r')
h5['poses'][0].shape
plot_3d(h5['poses'][1000])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-ff7ee62fcb3b> in <module>
#       1 path = '/home/datta/lab/HPE_datasets/h36m/S1/GT_3D'
# ----> 2 h5 = h5py.File(path+"Directions.54138969.h5", 'r')
#       3 h5['poses'][0].shape
#       4 plot_3d(h5['poses'][1000])
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
# ...

# %%
path = '/home/datta/lab/HPE_datasets/h36m/S1/SH_FT/'
h5 = h5py.File(path+"Directions_1.54138969.h5", 'r')
h5['poses'][0].shape
# plot_2d(h5['poses'][0])
print(h5['poses'][0][2])
# Out:
# (16, 2)
# [500. 449.]

# %%
path = '/home/datta/lab/HPE_datasets/h36m/S1/GT_2D/'
h5 = h5py.File(path+"Directions_1.54138969.h5", 'r')
h5['poses'][0].shape
print(h5['poses'][0])

path = '/home/datta/lab/HPE_datasets/h36m/S1/GT_3D/'
h5 = h5py.File(path+"Directions_1.54138969.h5", 'r')
h5['poses'][0].shape
print(h5['poses'][0])
# Out:
# (16, 2)
# [[473.68348786 444.94245906]
#  [500.99608771 448.02993804]
#  [479.83925221 530.78562293]
#  [506.21834233 622.56889693]
#  [445.90003904 441.81591347]
#  [456.1890454  537.15822789]
#  [467.30924988 633.76949986]
#  [488.18670488 397.43418997]
#  [481.02840777 340.39699571]
#  [485.76894374 297.57166567]
#  [454.01606634 359.75960243]
#  [430.05879548 415.7350289 ]
#  [412.99720366 452.88682258]
#  [508.13433956 356.49160671]
#  [520.31545985 413.31835327]
#  [515.47147726 456.42992518]]
# (16, 3)
# [[-176.73108  -321.04834  5203.882   ]
#  [ -52.961914 -309.7041   5251.0825  ]
#  [-155.6416     73.07178  5448.8066  ]
#  [ -29.831787  506.78467  5400.1387  ]
#  [-300.5      -332.39258  5156.6816  ]
#  [-258.24048    99.60986  5244.6807  ]
#  [-209.48425   548.8345   5290.7627  ]
#  [-109.15784  -529.72754  5123.891   ]
#  [-140.1914   -780.1211   5074.6045  ]
#  [-118.93494  -970.228    5058.599   ]
#  [-259.08997  -690.1333   5050.592   ]
# ...

# %%
path = '/home/datta/lab/HPE3D/src/data/h36m17_15678.h5'
h5 = h5py.File(path, 'r')
print(h5['pose2d'][0][0])
print(h5['pose3d'][0][0])
# Out:
# [473.68356 444.9424 ]
# [-176.73077 -321.0486  5203.882  ]

# %%
# %load_ext autoreload

# %autoreload 2

from src.dataset import H36M

data_file = f'../src/data/h36m_test_sh.h5'

dataset = H36M(data_file, train=True)

print("[INFO]: Length of the dataset: ", len(dataset))
print("[INFO]: One sample -")

sample = dataset.__getitem__(10)

from src.viz.mpl_plots import plot_2d, plot_3d
plot_2d(sample['pose2d'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [INFO]: processing data samples: 8608
# [INFO]: Length of the dataset:  8608
# [INFO]: One sample -

# %%
# %load_ext autoreload

# %autoreload 2

from src.dataset import H36M

data_file = f'../src/data/h36m_test_gt_2d.h5'

dataset = H36M(data_file, train=True)

print("[INFO]: Length of the dataset: ", len(dataset))
print("[INFO]: One sample -")

sample = dataset.__getitem__(10)

from src.viz.mpl_plots import plot_2d, plot_3d
plot_2d(sample['pose2d'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [INFO]: processing data samples: 8608
# [INFO]: Length of the dataset:  8608
# [INFO]: One sample -
